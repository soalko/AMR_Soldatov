# %% [markdown]
# Парная линейная регрессия
# Цель работы
#     Познакомиться с моделью парной линейной регрессии регрессии и методом градиентного спуска.
#
# Содержание работы
# Найти оценки параметров модели парной линейной регрессии прямыми вычислениями и палучить с помощью модели прогнозы результативного прознака.
# Найти оценки параметров модели парной линейной регрессии с использованием метода градиентного спуска.
# Оценить качество построенной модели, сравнив на графике обучающую выборку и прогнозы.
# Построить кривые обучения.

# %%
#Загрузим необходимые библиотеки
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize

# %%
#Исходные данные: x - расходы на рекламу, Y - объемы продаж
x = np.array([3, 5, 7, 6, 9])
Y = np.array([3, 7, 11, 14, 15])
display(x, Y)
# Out:
# array([3, 5, 7, 6, 9])
# array([ 3,  7, 11, 14, 15])

# %%
#Изобразим их на графике
plt.figure()
plt.scatter(x, Y)
plt.show()

# %%
#Вычислим оценки коэффициентов парной линейной регрессии по формулам
a1 = ((x - x.mean())*(Y - Y.mean())).mean()/((x - x.mean())**2).mean()
a0 = Y.mean() - a1*x.mean()
print("Модель линейной регрессии: Y^ = ", a0, " + ", a1, "* x")
# Out:
# Модель линейной регрессии: Y^ =  -2.0  +  2.0 * x

# %%
#Дадим серию прогнозов Y^ для x от 3 до 9 с шагом 1
x_space = np.linspace(3, 9, 7)
print(x_space)
Y_pred = a0 + a1*x_space
print(Y_pred)
# Out:
# [3. 4. 5. 6. 7. 8. 9.]
# [ 4.  6.  8. 10. 12. 14. 16.]

# %%
#Изобразим на графике исходные данные и прогнозы 
fig  = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.scatter(x, Y)
ax.plot(x_space, Y_pred, 'r')
#ax.scatter(x_space, Y_pred)

# %%
#Реализуем шаг градиентного спуска в модели парной лдинейной регрессии
class SimpleRegression(object):
    def __init__(self):
        self.a0 = 0
        self.a1 = 0
    def predict(self, x):
        return self.a0 + self.a1*x
    def MSE(self, x, Y):
        return ((self.predict(x)-Y)**2).mean()
    def fit(self, x, Y):
        alpha = 0.1
        dT_a0 = -2*sum((Y -self.predict(x)))
        dT_a1 = -2*sum((Y -self.predict(x))*x)
        self.a0 -= alpha*dT_a0
        self.a1 -= alpha*dT_a1

# %%
#Получим прогнозы до градиентного спуска с начальными значениями параметров
regr = SimpleRegression()
print(regr.predict(3))
print(regr.predict(5))
print(regr.predict(7))
print(regr.predict(6))
print(regr.predict(9))
print(regr.MSE(x, Y))
# Out:
# 0
# 0
# 0
# 0
# 0
# 120.0

# %%
#Выведем прогнозы до градиентного спуска на графике
x_space = np.linspace(3, 9, 7)
Y_pred = regr.predict(x_space)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.scatter(x, Y)
ax.plot(x_space, Y_pred, 'r')

# %%
#Реализуем шаг градиентного спуска
regr.fit(x, Y)
print("MSE после первого шага градиентного спуска: ", regr.MSE(x, Y))
Y_pred = regr.predict(x_space)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.scatter(x, Y)
ax.plot(x_space, Y_pred, 'r')
# Out:
# MSE после первого шага градиентного спуска:  183892.0

# %%
#Реализуем цикл градиентного спуска
class SimpleRegression(object):
    def __init__(self):
        self.a0 = 0
        self.a1 = 0
    def predict(self, x):
        return self.a0 + self.a1*x
    def MSE(self, x, Y):
        return ((Y - self.predict(x))**2).mean()
    def MAE(self, x, Y):
        return abs(Y - self.predict(x)).mean()
    def MAPE(self, x, Y):
        return abs((Y - self.predict(x))/Y).mean()
    def fit(self, x, Y, alpha = 0.001, epsylon = 0.01, max_steps = 5000):
        steps, errors = [], []
        step = 0
        for _ in range(max_steps):
            dT_a0 = -2*sum((Y -self.predict(x)))
            dT_a1 = -2*sum((Y -self.predict(x))*x)
            self.a0 -= alpha*dT_a0
            self.a1 -= alpha*dT_a1
            new_error = self.MSE(x, Y)
            step += 1
            steps.append(step)
            errors.append(new_error)
            if new_error < epsylon:
                break
        return steps, errors

# %%
#Запустим цикл градиентного спуска с заданной точностью 5
regr = SimpleRegression()
steps, errors = regr.fit(x, Y, alpha = 0.001, epsylon = 5)

# %%
#Выведем график прогнозов и вычислим MSE
print(regr.predict(3))
print(regr.predict(5))
print(regr.predict(7))
print(regr.predict(6))
print(regr.predict(9))
print("MSE после градиентного спуска: ", regr.MSE(x, Y))
Y_pred = regr.predict(x_space)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.scatter(x, Y)
ax.plot(x_space, Y_pred, 'r')
# Out:
# 5.004697916218
# 8.190462542210001
# 11.376227168202002
# 9.783344855206002
# 14.561991794194002
# MSE после градиентного спуска:  4.709918696051655

# %%
#Выведем график изменения MSE в процессе градиентного спуска
plt.figure()
plt.plot(steps, errors)

# %%
#Запустим цикл градиентного спуска с заданной точностью 0.05
regr = SimpleRegression()
steps, errors = regr.fit(x, Y, alpha = 0.001, epsylon = 0.05)

# %%
#Выведем график прогнозов и вычислим MSE
print("MSE после градиентного спуска: ", regr.MSE(x, Y))
Y_pred = regr.predict(x_space)
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])
ax.scatter(x, Y)
ax.plot(x_space, Y_pred, 'r')
# Out:
# MSE после градиентного спуска:  4.000028517306817

# %%
#Выведем график изменения MSE в процессе градиентного спуска
plt.figure()
plt.plot(steps, errors)

# %%
#Запустим цикл градиентного спуска с разными значениями скорости обучения alpha=0.0001, 0.01, 0.1, 1, 10, ..., 
#с различной допукстимой точностью epsylon = 0.001, 0.5, 5, с различным максимальным количеством шагов max_steps
regr = SimpleRegression()
steps, errors = regr.fit(x, Y, alpha = 0.0001, epsylon = 0.01, max_steps = 5000)
print("MSE после градиентного спуска: ", regr.MSE(x, Y))
Y_pred = regr.predict(x_space)
plt.figure()
plt.plot(steps, errors)
# Out:
# MSE после градиентного спуска:  4.1903709155046345

# %% [markdown]
# Загрузите файл Гиперспектр кукурузы.csv (с помощью pd.read_csv).
#
# 1. Вычислите аналитическим путем оценки коэффициентов парной линейной регрессии и постройте ее график.
# 2. Найдите оценки параметров модели парной лиенйной регрессии с использованием метода градиентного спуска. Постройте график.
# 3. Оцените качество построенных моделей сравнив на графике обучающую выборку и прогнозы.

# %%
import matplotlib.pyplot as plt

gipers = pd.read_csv(r"Гиперспектр кукурузы.csv", sep=";")
gipers.head()
Y = gipers['Spectr'].str.replace(',', '.').astype(float)[220:]
x = gipers['wavelength'].str.replace(',', '.').astype(float)[220:]
plt.figure()
plt.scatter(x, Y)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error

# =========================
# 1. Загрузка данных
# =========================
df = pd.read_csv(
    "Гиперспектр кукурузы.csv",
    sep=";",
    decimal=",",
    encoding="utf-8-sig"
)

# Срез [220:] — начиная с 221-й строки
data = df.iloc[220:].copy()

x = data["wavelength"].to_numpy(dtype=float)
y = data["Spectr"].to_numpy(dtype=float)

# =========================
# 2. Аналитическая парабола (МНК)
# y = a*x^2 + b*x + c
# =========================
Phi = np.column_stack([x**2, x, np.ones_like(x)])
beta = np.linalg.lstsq(Phi, y, rcond=None)[0]

a, b, c = beta
y_an = Phi @ beta

print("Аналитическая модель:")
print(f"a = {a:.10e}")
print(f"b = {b:.10e}")
print(f"c = {c:.10e}")
print(f"R2   = {r2_score(y, y_an):.5f}")
print(f"MSE  = {mean_squared_error(y, y_an):.6f}")
print(f"RMSE = {np.sqrt(mean_squared_error(y, y_an)):.6f}")

# =========================
# 3. Градиентный спуск
# Масштабируем x для устойчивости
# =========================
xm = x.mean()
xs = x.std()

t = (x - xm) / xs

# Признаки: 1, t, t^2
Xg = np.column_stack([np.ones_like(t), t, t**2])

theta = np.zeros(3)
alpha = 0.05
n_iter = 200000

for _ in range(n_iter):
    y_pred = Xg @ theta
    grad = (2 / len(y)) * Xg.T @ (y_pred - y)
    theta -= alpha * grad

y_gd = Xg @ theta

# Пересчёт коэффициентов обратно к исходной шкале x
th0, th1, th2 = theta

a_gd = th2 / xs**2
b_gd = th1 / xs - 2 * th2 * xm / xs**2
c_gd = th0 - th1 * xm / xs + th2 * xm**2 / xs**2

print("\nГрадиентный спуск:")
print(f"a_gd = {a_gd:.10e}")
print(f"b_gd = {b_gd:.10e}")
print(f"c_gd = {c_gd:.10e}")
print(f"R2   = {r2_score(y, y_gd):.5f}")
print(f"MSE  = {mean_squared_error(y, y_gd):.6f}")
print(f"RMSE = {np.sqrt(mean_squared_error(y, y_gd)):.6f}")

# =========================
# 4. График 1: аналитическая парабола
# =========================
plt.figure(figsize=(10, 6))
plt.scatter(x, y, s=25, color="black", label="Обучающая выборка")
plt.plot(x, y_an, color="red", linewidth=2, label="Аналитическая парабола (МНК)")
plt.xlabel("wavelength")
plt.ylabel("Spectr")
plt.title("Пункт 1: аналитическая параболическая регрессия")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# =========================
# 5. График 2: градиентный спуск
# =========================
plt.figure(figsize=(10, 6))
plt.scatter(x, y, s=25, color="black", label="Обучающая выборка")
plt.plot(x, y_gd, color="green", linewidth=2, linestyle="--", label="Парабола, градиентный спуск")
plt.xlabel("wavelength")
plt.ylabel("Spectr")
plt.title("Пункт 2: параболическая регрессия через градиентный спуск")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()

# =========================
# 6. График 3: сравнение обучающей выборки и прогнозов
# =========================
plt.figure(figsize=(11, 6))
plt.scatter(x, y, s=25, color="black", label="Обучающая выборка")
plt.plot(x, y_an, color="red", linewidth=2, label="Аналитическая парабола (МНК)")
plt.plot(x, y_gd, color="green", linewidth=2, linestyle="--", label="Градиентный спуск")

# Можно добавить текстовую информацию о качестве моделей
plt.text(
    0.02, 0.98,
    f"Аналитическая: R²={r2_score(y, y_an):.4f}, RMSE={np.sqrt(mean_squared_error(y, y_an)):.4f}\n"
    f"Градиентный спуск: R²={r2_score(y, y_gd):.4f}, RMSE={np.sqrt(mean_squared_error(y, y_gd)):.4f}",
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment="top",
    bbox=dict(boxstyle="round", facecolor="white", alpha=0.8)
)

plt.xlabel("wavelength")
plt.ylabel("Spectr")
plt.title("Пункт 3: сравнение обучающей выборки и прогнозов")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Аналитическая модель:
# a = 1.3103709197e-04
# b = -2.4689714039e-01
# c = 1.1646249161e+02
# R2   = 0.87837
# MSE  = 0.002547
# RMSE = 0.050469
#
# Градиентный спуск:
# a_gd = 1.3103709197e-04
# b_gd = -2.4689714039e-01
# c_gd = 1.1646249161e+02
# R2   = 0.87837
# MSE  = 0.002547
# RMSE = 0.050469
